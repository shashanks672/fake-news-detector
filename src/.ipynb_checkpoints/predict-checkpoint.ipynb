# %%
import joblib

# %%
model = joblib.load("/Users/shashanks/fake-news-detector/models/fake_news_model.pkl")
vectorizer = joblib.load("/Users/shashanks/fake-news-detector/models/tfidf_vectorizer.pkl")

# %%
sample_news = ["Breaking news! Scientists discovered aliens on Mars."]

# %%
sample_vector = vectorizer.transform(sample_news)

# %%
predict= model.predict(sample_vector)
if predict[0] == 0 :
    print("This is fake News ")
else:
    print("it's not a Fake News")
# Out:
# This is fake News
